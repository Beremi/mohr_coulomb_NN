# %% [markdown]
# # Mohr-Coulomb Long Adam Plateau Training
#
# This notebook is the long-running training version of the surrogate example. It keeps the same basic workflow as the short demo, but switches to a much larger Adam run:
#
# - `10000` Adam epochs maximum,
# - `ReduceLROnPlateau` scheduler,
# - plateau factor `0.5`,
# - scheduler patience `100`,
# - early-stopping patience `100`,
# - progress printed every `100` epochs.
#
# This is intentionally not the quick notebook. It is meant as a heavier optimization example.

# %% [markdown]
# ## Environment setup
#
# Resolve the repository root, add `src/` to the import path, and define output locations for the generated data, run directory, and evaluation plots.

# %%
from pathlib import Path
import json
import random
import sys

import numpy as np
import torch

ROOT = Path.cwd()
if not (ROOT / "src").exists() and (ROOT.parent / "src").exists():
    ROOT = ROOT.parent

SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

OUTPUT_ROOT = ROOT / "notebook_runs" / "long_plateau_adam"
DATA_PATH = OUTPUT_ROOT / "mc_long_plateau.h5"
RUN_DIR = OUTPUT_ROOT / "principal_long_plateau"
EVAL_DIR = RUN_DIR / "eval"

OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)
RUN_DIR.mkdir(parents=True, exist_ok=True)
EVAL_DIR.mkdir(parents=True, exist_ok=True)

seed = 7
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Repository root: {ROOT}")
print(f"Torch device: {device}")
print(f"Outputs: {OUTPUT_ROOT}")
# Out:
# Repository root: /home/beremi/repos/mohr_coulomb_NN
# Torch device: cuda
# Outputs: /home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam

# %% [markdown]
# ## 1. Generate a focused training dataset
#
# This uses the same focused parameter window and principal-strain cap that produced the stable demo dataset, but with a larger sample count so the long Adam run has more data to work with.

# %%
import h5py

from mc_surrogate.data import dataset_summary
from mc_surrogate.sampling import DatasetGenerationConfig, MaterialRangeConfig, generate_branch_balanced_dataset

material_ranges = MaterialRangeConfig(
    cohesion_range=(5.0, 25.0),
    friction_deg_range=(25.0, 45.0),
    dilatancy_deg_range=(0.0, 10.0),
    young_range=(1.0e4, 6.0e4),
    poisson_range=(0.25, 0.38),
    strength_reduction_range=(0.9, 2.0),
)

dataset_cfg = DatasetGenerationConfig(
    n_samples=10000,
    seed=seed,
    candidate_batch=1536,
    include_tangent=False,
    max_abs_principal_strain=2.0e-3,
    material_ranges=material_ranges,
)

branch_counts = generate_branch_balanced_dataset(str(DATA_PATH), dataset_cfg)
summary = dataset_summary(DATA_PATH)
with h5py.File(DATA_PATH, "r") as f:
    rowmax_stress = np.max(np.abs(f["stress"][:]), axis=1)

print("Branch counts:")
print(json.dumps(branch_counts, indent=2))
print("\nDataset summary:")
print(json.dumps(summary, indent=2))
print("\nStress max-abs quantiles:")
print(np.quantile(rowmax_stress, [0.0, 0.5, 0.9, 0.99, 1.0]))
# Out:
# Branch counts:
# {
#   "elastic": 2000,
#   "smooth": 2000,
#   "left_edge": 2000,
#   "right_edge": 2000,
#   "apex": 2000
# }
#
# Dataset summary:
# {
#   "path": "/home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/mc_long_plateau.h5",
#   "n_samples": 10000,
#   "contains_tangent": false,
#   "branch_names": [
#     "elastic",
#     "smooth",
#     "left_edge",
#     "right_edge",
#     "apex"
#   ],
#   "raw_material_columns": [
#     "c0",
#     "phi_deg",
#     "psi_deg",
#     "young",
#     "poisson",
#     "strength_reduction",
#     "davis_id"
#   ],
#   "reduced_material_columns": [
#     "c_bar",
#     "sin_phi",
#     "shear",
#     "bulk",
#     "lame"
#   ],
#   "split_counts": {
#     "train": 8000,
#     "val": 1000,
#     "test": 1000
#   },
#   "branch_counts": {
#     "elastic": 2000,
#     "smooth": 2000,
#     "left_edge": 2000,
#     "right_edge": 2000,
#     "apex": 2000
#   }
# }
#
# Stress max-abs quantiles:
# [2.50952310e-03 8.73519520e+00 2.07440180e+01 3.53649054e+01
#  1.32331229e+02]

# %% [markdown]
# ## 2. Configure the larger network and long Adam run
#
# This cell sets up the larger principal-stress network and the long plateau-based Adam schedule. The trainer will print status every `100` epochs.

# %%
from mc_surrogate.models import build_model
from mc_surrogate.training import TrainingConfig

config = TrainingConfig(
    dataset=str(DATA_PATH),
    run_dir=str(RUN_DIR),
    model_kind="principal",
    epochs=10000,
    batch_size=2048,
    lr=1.0e-3,
    weight_decay=5.0e-5,
    width=512,
    depth=8,
    dropout=0.0,
    seed=seed,
    patience=1000,
    grad_clip=1.0,
    branch_loss_weight=0.05,
    num_workers=0,
    device=device,
    scheduler_kind="plateau",
    min_lr=1.0e-6,
    plateau_factor=0.5,
    plateau_patience=100,
    lbfgs_epochs=0,
    log_every_epochs=100,
)

model = build_model(
    model_kind=config.model_kind,
    input_dim=11,
    width=config.width,
    depth=config.depth,
    dropout=config.dropout,
)
n_params = sum(p.numel() for p in model.parameters())

print(model)
print(f"\nTrainable parameters: {n_params:,}")
print("\nTraining configuration:")
print(json.dumps(config.__dict__, indent=2))
# Out:
# PrincipalStressNet(
#   (input): Sequential(
#     (0): Linear(in_features=11, out_features=512, bias=True)
#     (1): GELU(approximate='none')
#   )
#   (blocks): ModuleList(
#     (0-7): 8 x ResidualBlock(
#       (net): Sequential(
#         (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (1): Linear(in_features=512, out_features=512, bias=True)
#         (2): GELU(approximate='none')
#         (3): Dropout(p=0.0, inplace=False)
#         (4): Linear(in_features=512, out_features=512, bias=True)
#       )
#       (out_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (act): GELU(approximate='none')
#     )
#   )
#   (head_stress): Linear(in_features=512, out_features=3, bias=True)
#   (head_branch): Linear(in_features=512, out_features=5, bias=True)
# )
#
# Trainable parameters: 4,229,128
#
# Training configuration:
# {
#   "dataset": "/home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/mc_long_plateau.h5",
#   "run_dir": "/home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/principal_long_plateau",
#   "model_kind": "principal",
#   "epochs": 10000,
#   "batch_size": 2048,
#   "lr": 0.001,
#   "weight_decay": 5e-05,
#   "width": 512,
#   "depth": 8,
#   "dropout": 0.0,
#   "seed": 7,
#   "patience": 1000,
#   "grad_clip": 1.0,
#   "branch_loss_weight": 0.05,
#   "num_workers": 0,
#   "device": "cuda",
#   "scheduler_kind": "plateau",
#   "warmup_epochs": 0,
#   "min_lr": 1e-06,
#   "plateau_factor": 0.5,
#   "plateau_patience": 100,
#   "lbfgs_epochs": 0,
#   "lbfgs_lr": 0.25,
#   "lbfgs_max_iter": 20,
#   "lbfgs_history_size": 100,
#   "log_every_epochs": 100
# }

# %% [markdown]
# ## 3. Train the surrogate
#
# This runs the long Adam training schedule. Training stops when either `10000` epochs are reached or validation loss fails to improve for `100` epochs. The trainer prints one progress line every `100` epochs.

# %%
from mc_surrogate.training import train_model

train_summary = train_model(config)
print(json.dumps(train_summary, indent=2))
# Out:
# [Adam] epoch=1 lr=1.000e-03 train_loss=1.051286 val_loss=0.407249 train_stress_mse=32.156859 val_stress_mse=10.948463 best_val=0.407249
# [Adam] epoch=100 lr=1.000e-03 train_loss=0.046393 val_loss=0.046495 train_stress_mse=1.219657 val_stress_mse=1.070686 best_val=0.036091
# [Adam] epoch=200 lr=1.000e-03 train_loss=0.036526 val_loss=0.039976 train_stress_mse=0.919391 val_stress_mse=0.901613 best_val=0.034731
# [Adam] epoch=300 lr=5.000e-04 train_loss=0.034602 val_loss=0.035726 train_stress_mse=0.874616 val_stress_mse=0.889185 best_val=0.033690
# [Adam] epoch=400 lr=5.000e-04 train_loss=0.034094 val_loss=0.033663 train_stress_mse=0.863341 val_stress_mse=0.837406 best_val=0.033270
# [Adam] epoch=500 lr=5.000e-04 train_loss=0.034530 val_loss=0.033154 train_stress_mse=0.871130 val_stress_mse=0.827451 best_val=0.033143
# [Adam] epoch=600 lr=5.000e-04 train_loss=0.036730 val_loss=0.035556 train_stress_mse=0.930422 val_stress_mse=0.898696 best_val=0.033078
# [Adam] epoch=700 lr=2.500e-04 train_loss=0.033538 val_loss=0.033650 train_stress_mse=0.845389 val_stress_mse=0.839527 best_val=0.033078
# [Adam] epoch=800 lr=2.500e-04 train_loss=0.033775 val_loss=0.033110 train_stress_mse=0.852938 val_stress_mse=0.815466 best_val=0.032918
# [Adam] epoch=900 lr=2.500e-04 train_loss=0.034249 val_loss=0.033330 train_stress_mse=0.872234 val_stress_mse=0.837445 best_val=0.032834
# [Adam] epoch=1000 lr=1.250e-04 train_loss=0.033294 val_loss=0.032893 train_stress_mse=0.840122 val_stress_mse=0.817029 best_val=0.032724
# [Adam] epoch=1100 lr=1.250e-04 train_loss=0.033183 val_loss=0.032933 train_stress_mse=0.837482 val_stress_mse=0.816736 best_val=0.032713
# [Adam] epoch=1200 lr=6.250e-05 train_loss=0.033013 val_loss=0.032689 train_stress_mse=0.833134 val_stress_mse=0.811159 best_val=0.032606
# [Adam] epoch=1300 lr=3.125e-05 train_loss=0.032983 val_loss=0.032589 train_stress_mse=0.832424 val_stress_mse=0.808537 best_val=0.032589
# [Adam] epoch=1400 lr=3.125e-05 train_loss=0.032973 val_loss=0.032574 train_stress_mse=0.832010 val_stress_mse=0.807860 best_val=0.032559
# [Adam] epoch=1500 lr=3.125e-05 train_loss=0.032988 val_loss=0.032596 train_stress_mse=0.832227 val_stress_mse=0.809331 best_val=0.032545
# [Adam] epoch=1600 lr=3.125e-05 train_loss=0.032940 val_loss=0.032541 train_stress_mse=0.831485 val_stress_mse=0.807337 best_val=0.032530
# [Adam] epoch=1700 lr=3.125e-05 train_loss=0.032980 val_loss=0.032548 train_stress_mse=0.832400 val_stress_mse=0.807308 best_val=0.032514
# [Adam] epoch=1800 lr=3.125e-05 train_loss=0.032996 val_loss=0.032570 train_stress_mse=0.833047 val_stress_mse=0.808279 best_val=0.032501
# [Adam] epoch=1900 lr=3.125e-05 train_loss=0.032966 val_loss=0.032491 train_stress_mse=0.832356 val_stress_mse=0.806164 best_val=0.032475
# [Adam] epoch=2000 lr=3.125e-05 train_loss=0.032991 val_loss=0.032594 train_stress_mse=0.833240 val_stress_mse=0.808177 best_val=0.032448
# [Adam] epoch=2100 lr=3.125e-05 train_loss=0.033009 val_loss=0.032625 train_stress_mse=0.833348 val_stress_mse=0.809680 best_val=0.032444
# [Adam] epoch=2200 lr=3.125e-05 train_loss=0.033010 val_loss=0.032473 train_stress_mse=0.833211 val_stress_mse=0.808231 best_val=0.032436
# [Adam] epoch=2300 lr=3.125e-05 train_loss=0.033023 val_loss=0.032460 train_stress_mse=0.833790 val_stress_mse=0.807764 best_val=0.032414
# [Adam] epoch=2400 lr=1.563e-05 train_loss=0.032942 val_loss=0.032414 train_stress_mse=0.831483 val_stress_mse=0.805466 best_val=0.032393
# [Adam] epoch=2500 lr=7.813e-06 train_loss=0.032905 val_loss=0.032394 train_stress_mse=0.830537 val_stress_mse=0.804911 best_val=0.032392
# [Adam] epoch=2600 lr=7.813e-06 train_loss=0.032906 val_loss=0.032388 train_stress_mse=0.830546 val_stress_mse=0.804833 best_val=0.032383
# [Adam] epoch=2700 lr=7.813e-06 train_loss=0.032908 val_loss=0.032383 train_stress_mse=0.830618 val_stress_mse=0.804599 best_val=0.032379
# [Adam] epoch=2800 lr=3.906e-06 train_loss=0.032904 val_loss=0.032386 train_stress_mse=0.830541 val_stress_mse=0.804583 best_val=0.032379
# [Adam] epoch=2900 lr=1.953e-06 train_loss=0.032897 val_loss=0.032382 train_stress_mse=0.830356 val_stress_mse=0.804436 best_val=0.032378
# [Adam] epoch=3000 lr=1.000e-06 train_loss=0.032896 val_loss=0.032382 train_stress_mse=0.830339 val_stress_mse=0.804414 best_val=0.032378
# [Adam] epoch=3100 lr=1.000e-06 train_loss=0.032896 val_loss=0.032382 train_stress_mse=0.830343 val_stress_mse=0.804403 best_val=0.032378
# [Adam] epoch=3200 lr=1.000e-06 train_loss=0.032895 val_loss=0.032380 train_stress_mse=0.830305 val_stress_mse=0.804344 best_val=0.032378
# [Adam] epoch=3300 lr=1.000e-06 train_loss=0.032896 val_loss=0.032379 train_stress_mse=0.830329 val_stress_mse=0.804339 best_val=0.032378
# [Adam] epoch=3400 lr=1.000e-06 train_loss=0.032895 val_loss=0.032377 train_stress_mse=0.830314 val_stress_mse=0.804273 best_val=0.032376
# [Adam] epoch=3500 lr=1.000e-06 train_loss=0.032894 val_loss=0.032377 train_stress_mse=0.830357 val_stress_mse=0.804300 best_val=0.032376
# [Adam] epoch=3600 lr=1.000e-06 train_loss=0.032894 val_loss=0.032376 train_stress_mse=0.830305 val_stress_mse=0.804265 best_val=0.032375
# [Adam] epoch=3700 lr=1.000e-06 train_loss=0.032894 val_loss=0.032376 train_stress_mse=0.830313 val_stress_mse=0.804264 best_val=0.032374
# [Adam] epoch=3800 lr=1.000e-06 train_loss=0.032894 val_loss=0.032374 train_stress_mse=0.830284 val_stress_mse=0.804257 best_val=0.032374
# [Adam] epoch=3900 lr=1.000e-06 train_loss=0.032893 val_loss=0.032375 train_stress_mse=0.830290 val_stress_mse=0.804244 best_val=0.032373
# [Adam] epoch=4000 lr=1.000e-06 train_loss=0.032893 val_loss=0.032372 train_stress_mse=0.830316 val_stress_mse=0.804218 best_val=0.032371
# [Adam] epoch=4100 lr=1.000e-06 train_loss=0.032893 val_loss=0.032372 train_stress_mse=0.830289 val_stress_mse=0.804222 best_val=0.032370
# [Adam] epoch=4200 lr=1.000e-06 train_loss=0.032893 val_loss=0.032370 train_stress_mse=0.830258 val_stress_mse=0.804173 best_val=0.032369
# [Adam] epoch=4300 lr=1.000e-06 train_loss=0.032892 val_loss=0.032369 train_stress_mse=0.830275 val_stress_mse=0.804147 best_val=0.032368
# [Adam] epoch=4400 lr=1.000e-06 train_loss=0.032892 val_loss=0.032368 train_stress_mse=0.830276 val_stress_mse=0.804119 best_val=0.032366
# [Adam] epoch=4500 lr=1.000e-06 train_loss=0.032892 val_loss=0.032366 train_stress_mse=0.830264 val_stress_mse=0.804116 best_val=0.032366
# [Adam] epoch=4600 lr=1.000e-06 train_loss=0.032892 val_loss=0.032367 train_stress_mse=0.830298 val_stress_mse=0.804092 best_val=0.032365
# [Adam] epoch=4700 lr=1.000e-06 train_loss=0.032892 val_loss=0.032364 train_stress_mse=0.830264 val_stress_mse=0.804027 best_val=0.032363
# [Adam] epoch=4800 lr=1.000e-06 train_loss=0.032891 val_loss=0.032365 train_stress_mse=0.830228 val_stress_mse=0.804059 best_val=0.032363
# [Adam] epoch=4900 lr=1.000e-06 train_loss=0.032892 val_loss=0.032364 train_stress_mse=0.830201 val_stress_mse=0.804024 best_val=0.032361
# [Adam] epoch=5000 lr=1.000e-06 train_loss=0.032891 val_loss=0.032365 train_stress_mse=0.830211 val_stress_mse=0.804031 best_val=0.032361
# [Adam] epoch=5100 lr=1.000e-06 train_loss=0.032891 val_loss=0.032364 train_stress_mse=0.830207 val_stress_mse=0.803933 best_val=0.032361
# [Adam] epoch=5200 lr=1.000e-06 train_loss=0.032891 val_loss=0.032362 train_stress_mse=0.830212 val_stress_mse=0.803922 best_val=0.032361
# [Adam] epoch=5300 lr=1.000e-06 train_loss=0.032891 val_loss=0.032364 train_stress_mse=0.830213 val_stress_mse=0.803958 best_val=0.032360
# [Adam] epoch=5400 lr=1.000e-06 train_loss=0.032890 val_loss=0.032362 train_stress_mse=0.830239 val_stress_mse=0.803918 best_val=0.032360
# [Adam] epoch=5500 lr=1.000e-06 train_loss=0.032891 val_loss=0.032361 train_stress_mse=0.830234 val_stress_mse=0.803925 best_val=0.032359
# [Adam] epoch=5600 lr=1.000e-06 train_loss=0.032890 val_loss=0.032359 train_stress_mse=0.830202 val_stress_mse=0.803861 best_val=0.032358
# [Adam] epoch=5700 lr=1.000e-06 train_loss=0.032890 val_loss=0.032359 train_stress_mse=0.830216 val_stress_mse=0.803836 best_val=0.032358
# [Adam] epoch=5800 lr=1.000e-06 train_loss=0.032890 val_loss=0.032359 train_stress_mse=0.830218 val_stress_mse=0.803843 best_val=0.032356
# [Adam] epoch=5900 lr=1.000e-06 train_loss=0.032890 val_loss=0.032358 train_stress_mse=0.830212 val_stress_mse=0.803822 best_val=0.032356
# [Adam] epoch=6000 lr=1.000e-06 train_loss=0.032889 val_loss=0.032358 train_stress_mse=0.830186 val_stress_mse=0.803790 best_val=0.032356
# [Adam] epoch=6100 lr=1.000e-06 train_loss=0.032890 val_loss=0.032355 train_stress_mse=0.830211 val_stress_mse=0.803776 best_val=0.032354
# [Adam] epoch=6200 lr=1.000e-06 train_loss=0.032889 val_loss=0.032356 train_stress_mse=0.830212 val_stress_mse=0.803779 best_val=0.032354
# [Adam] epoch=6300 lr=1.000e-06 train_loss=0.032889 val_loss=0.032354 train_stress_mse=0.830182 val_stress_mse=0.803753 best_val=0.032352
# [Adam] epoch=6400 lr=1.000e-06 train_loss=0.032889 val_loss=0.032354 train_stress_mse=0.830162 val_stress_mse=0.803710 best_val=0.032352
# [Adam] epoch=6500 lr=1.000e-06 train_loss=0.032889 val_loss=0.032354 train_stress_mse=0.830179 val_stress_mse=0.803701 best_val=0.032351
# [Adam] epoch=6600 lr=1.000e-06 train_loss=0.032889 val_loss=0.032352 train_stress_mse=0.830203 val_stress_mse=0.803741 best_val=0.032351
# [Adam] epoch=6700 lr=1.000e-06 train_loss=0.032889 val_loss=0.032352 train_stress_mse=0.830179 val_stress_mse=0.803680 best_val=0.032349
# [Adam] epoch=6800 lr=1.000e-06 train_loss=0.032889 val_loss=0.032351 train_stress_mse=0.830149 val_stress_mse=0.803672 best_val=0.032349
# [Adam] epoch=6900 lr=1.000e-06 train_loss=0.032890 val_loss=0.032349 train_stress_mse=0.830205 val_stress_mse=0.803665 best_val=0.032349
# [Adam] epoch=7000 lr=1.000e-06 train_loss=0.032889 val_loss=0.032349 train_stress_mse=0.830171 val_stress_mse=0.803596 best_val=0.032346
# [Adam] epoch=7100 lr=1.000e-06 train_loss=0.032889 val_loss=0.032349 train_stress_mse=0.830147 val_stress_mse=0.803636 best_val=0.032346
# [Adam] epoch=7200 lr=1.000e-06 train_loss=0.032888 val_loss=0.032347 train_stress_mse=0.830145 val_stress_mse=0.803605 best_val=0.032345
# [Adam] epoch=7300 lr=1.000e-06 train_loss=0.032888 val_loss=0.032346 train_stress_mse=0.830138 val_stress_mse=0.803597 best_val=0.032345
# [Adam] epoch=7400 lr=1.000e-06 train_loss=0.032888 val_loss=0.032346 train_stress_mse=0.830126 val_stress_mse=0.803547 best_val=0.032344
# [Adam] epoch=7500 lr=1.000e-06 train_loss=0.032888 val_loss=0.032344 train_stress_mse=0.830135 val_stress_mse=0.803568 best_val=0.032343
# [Adam] epoch=7600 lr=1.000e-06 train_loss=0.032888 val_loss=0.032343 train_stress_mse=0.830149 val_stress_mse=0.803560 best_val=0.032341
# [Adam] epoch=7700 lr=1.000e-06 train_loss=0.032888 val_loss=0.032343 train_stress_mse=0.830150 val_stress_mse=0.803564 best_val=0.032341
# [Adam] epoch=7800 lr=1.000e-06 train_loss=0.032888 val_loss=0.032343 train_stress_mse=0.830136 val_stress_mse=0.803547 best_val=0.032341
# [Adam] epoch=7900 lr=1.000e-06 train_loss=0.032888 val_loss=0.032341 train_stress_mse=0.830160 val_stress_mse=0.803535 best_val=0.032340
# [Adam] epoch=8000 lr=1.000e-06 train_loss=0.032888 val_loss=0.032340 train_stress_mse=0.830169 val_stress_mse=0.803510 best_val=0.032339
# [Adam] epoch=8100 lr=1.000e-06 train_loss=0.032888 val_loss=0.032339 train_stress_mse=0.830133 val_stress_mse=0.803445 best_val=0.032338
# [Adam] epoch=8200 lr=1.000e-06 train_loss=0.032888 val_loss=0.032338 train_stress_mse=0.830151 val_stress_mse=0.803437 best_val=0.032337
# [Adam] epoch=8300 lr=1.000e-06 train_loss=0.032889 val_loss=0.032338 train_stress_mse=0.830149 val_stress_mse=0.803476 best_val=0.032337
# [Adam] epoch=8400 lr=1.000e-06 train_loss=0.032887 val_loss=0.032338 train_stress_mse=0.830154 val_stress_mse=0.803408 best_val=0.032336
# [Adam] epoch=8500 lr=1.000e-06 train_loss=0.032887 val_loss=0.032338 train_stress_mse=0.830131 val_stress_mse=0.803480 best_val=0.032335
# [Adam] epoch=8600 lr=1.000e-06 train_loss=0.032887 val_loss=0.032336 train_stress_mse=0.830119 val_stress_mse=0.803418 best_val=0.032335
# [Adam] epoch=8700 lr=1.000e-06 train_loss=0.032888 val_loss=0.032335 train_stress_mse=0.830155 val_stress_mse=0.803407 best_val=0.032333
# [Adam] epoch=8800 lr=1.000e-06 train_loss=0.032888 val_loss=0.032336 train_stress_mse=0.830142 val_stress_mse=0.803422 best_val=0.032333
# [Adam] epoch=8900 lr=1.000e-06 train_loss=0.032888 val_loss=0.032334 train_stress_mse=0.830166 val_stress_mse=0.803416 best_val=0.032333
# [Adam] epoch=9000 lr=1.000e-06 train_loss=0.032887 val_loss=0.032333 train_stress_mse=0.830147 val_stress_mse=0.803390 best_val=0.032332
# [Adam] epoch=9100 lr=1.000e-06 train_loss=0.032887 val_loss=0.032333 train_stress_mse=0.830124 val_stress_mse=0.803352 best_val=0.032331
# [Adam] epoch=9200 lr=1.000e-06 train_loss=0.032887 val_loss=0.032334 train_stress_mse=0.830149 val_stress_mse=0.803344 best_val=0.032331
# [Adam] epoch=9300 lr=1.000e-06 train_loss=0.032887 val_loss=0.032332 train_stress_mse=0.830157 val_stress_mse=0.803336 best_val=0.032329
# [Adam] epoch=9400 lr=1.000e-06 train_loss=0.032887 val_loss=0.032331 train_stress_mse=0.830122 val_stress_mse=0.803334 best_val=0.032329
# [Adam] epoch=9500 lr=1.000e-06 train_loss=0.032886 val_loss=0.032330 train_stress_mse=0.830107 val_stress_mse=0.803285 best_val=0.032329
# [Adam] epoch=9600 lr=1.000e-06 train_loss=0.032886 val_loss=0.032330 train_stress_mse=0.830097 val_stress_mse=0.803289 best_val=0.032328
# [Adam] epoch=9700 lr=1.000e-06 train_loss=0.032886 val_loss=0.032329 train_stress_mse=0.830123 val_stress_mse=0.803258 best_val=0.032327
# [Adam] epoch=9800 lr=1.000e-06 train_loss=0.032887 val_loss=0.032330 train_stress_mse=0.830116 val_stress_mse=0.803248 best_val=0.032327
# [Adam] epoch=9900 lr=1.000e-06 train_loss=0.032886 val_loss=0.032328 train_stress_mse=0.830116 val_stress_mse=0.803272 best_val=0.032326
# [Adam] epoch=10000 lr=1.000e-06 train_loss=0.032888 val_loss=0.032328 train_stress_mse=0.830150 val_stress_mse=0.803252 best_val=0.032326
# {
#   "best_val_loss": 0.03232584893703461,
#   "best_epoch": 9842,
#   "completed_epochs": 10000,
#   "run_dir": "/home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/principal_long_plateau",
#   "best_checkpoint": "/home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/principal_long_plateau/best.pt",
#   "history_csv": "/home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/principal_long_plateau/history.csv",
#   "device": "cuda"
# }

# %% [markdown]
# ## 4. Visualize and validate
#
# Once training finishes, evaluate the best checkpoint, save plots, and compare it on a representative triaxial loading path.

# %%
from IPython.display import Image, display

from mc_surrogate.inference import ConstitutiveSurrogate
from mc_surrogate.materials import build_reduced_material_from_raw
from mc_surrogate.mohr_coulomb import constitutive_update_3d
from mc_surrogate.training import evaluate_checkpoint_on_dataset
from mc_surrogate.viz import (
    branch_confusion_plot,
    error_histogram,
    parity_plot,
    plot_path_comparison,
    plot_training_history,
    save_metrics_json,
)
from mc_surrogate.voigt import tensor_to_strain_voigt

history_png = plot_training_history(RUN_DIR / "history.csv", EVAL_DIR / "history.png")

result = evaluate_checkpoint_on_dataset(
    checkpoint_path=RUN_DIR / "best.pt",
    dataset_path=DATA_PATH,
    split="test",
    device=device,
)

metrics = result["metrics"]
arrays = result["arrays"]
pred = result["predictions"]

metrics_json = save_metrics_json(metrics, EVAL_DIR / "metrics.json")
parity_png = parity_plot(arrays["stress"], pred["stress"], EVAL_DIR / "parity_stress.png", label="stress")
error_png = error_histogram(pred["stress"] - arrays["stress"], EVAL_DIR / "stress_error_hist.png", label="stress error")

branch_png = None
if "branch_confusion" in metrics:
    branch_png = branch_confusion_plot(metrics["branch_confusion"], EVAL_DIR / "branch_confusion.png")

t = np.linspace(0.0, 1.0, 150)
principal_strain = np.column_stack([2.0 * t, -1.0 * t, -1.0 * t]) * 1.0e-3
rotations = np.repeat(np.eye(3)[None, :, :], t.size, axis=0)
strain_eng = tensor_to_strain_voigt(np.einsum("nij,nj,nkj->nik", rotations, principal_strain, rotations))

reduced = build_reduced_material_from_raw(
    c0=np.full(t.size, 15.0),
    phi_rad=np.deg2rad(np.full(t.size, 35.0)),
    psi_rad=np.deg2rad(np.full(t.size, 0.0)),
    young=np.full(t.size, 2.0e4),
    poisson=np.full(t.size, 0.30),
    strength_reduction=np.full(t.size, 1.2),
    davis_type=["B"] * t.size,
)

exact = constitutive_update_3d(
    strain_eng,
    c_bar=reduced.c_bar,
    sin_phi=reduced.sin_phi,
    shear=reduced.shear,
    bulk=reduced.bulk,
    lame=reduced.lame,
)
surrogate = ConstitutiveSurrogate.from_checkpoint(RUN_DIR / "best.pt", device=device)
path_pred = surrogate.predict_reduced(
    strain_eng,
    c_bar=reduced.c_bar,
    sin_phi=reduced.sin_phi,
    shear=reduced.shear,
    bulk=reduced.bulk,
    lame=reduced.lame,
)
path_png = plot_path_comparison(
    t,
    exact.stress_principal,
    path_pred["stress_principal"],
    EVAL_DIR / "path_comparison.png",
    title="Triaxial loading path: exact vs surrogate",
)

print(json.dumps(metrics, indent=2))
print(f"\nMetrics saved to: {metrics_json}")

for image_path in [history_png, parity_png, error_png, branch_png, path_png]:
    if image_path is not None:
        display(Image(filename=image_path))
# Out:
# {
#   "split": "test",
#   "n_samples": 1000,
#   "stress_mae": 0.7155188778779933,
#   "stress_rmse": 0.9648700527790411,
#   "stress_max_abs": 5.054168592531795,
#   "per_component_mae": [
#     0.7507793749653395,
#     0.7788312803110037,
#     0.7857911418860787,
#     0.6473349085517793,
#     0.6744108599129542,
#     0.6559657016408046
#   ],
#   "principal_mae": 1.2402238990368837,
#   "principal_rmse": 1.6281638851239015,
#   "branch_accuracy": 0.999,
#   "branch_confusion": [
#     [
#       211,
#       0,
#       0,
#       0,
#       0
#     ],
#     [
#       0,
#       193,
#       1,
#       0,
#       0
#     ],
#     [
#       0,
#       0,
#       203,
#       0,
#       0
#     ],
#     [
#       0,
#       0,
#       0,
#       191,
#       0
#     ],
#     [
#       0,
#       0,
#       0,
#       0,
#       201
#     ]
#   ],
#   "per_branch_stress_mae": {
#     "elastic": 0.938781809725295,
#     "smooth": 0.3426585512150166,
#     "left_edge": 0.6112262365484334,
#     "right_edge": 0.7112480113249441,
#     "apex": 0.9504122433226194
#   }
# }
#
# Metrics saved to: /home/beremi/repos/mohr_coulomb_NN/notebook_runs/long_plateau_adam/principal_long_plateau/eval/metrics.json
